# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, FloatSlider, IntSlider
import time

# %% [markdown]
# # Descente de gradient
# Ecrivez à la main le code de descente de gradient pour optimiser un perceptron pour faire de la classification linéaire

# %%
# Génération de données
np.random.seed(0)
num_samples = 200
X = np.random.randn(num_samples, 2)
y = (X[:, 0] + 2 * X[:, 1] +2 > 0).astype(int) * 2 - 1  # Labels -1 ou 1 suivant le signe de x1 + 2* x2 + 2

plt.figure(figsize=(10, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', marker='o', edgecolor='k')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %%
# Initialisation des poids et du biais
np.random.seed(10)
weights = np.random.randn(2)
bias = np.random.randn()
#learning_rate = 
#epochs = 

# Fonction d'activation (fonction signe)
def sign_activation(x):
    return np.where(x >= 0, 1, -1)

# loss (Mean Squared Error)
def mse_loss(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# Boucle d'entraînement
loss_history = []
for epoch in range(epochs):
    # Calcul des prédictions
    
    # Calcul de la loss
    #loss =
    #loss_history.append(loss)
    
    # Calcul des gradients
    errors = y - y_pred
    #dweights = 
    #dbias = 
    
    # Mise à jour des poids et du biais
    weights -= learning_rate * dweights
    bias -= learning_rate * dbias
    
   # # Visualisation de la frontière de décision
   # if epoch % 5 == 0 or epoch == epochs - 1:
   #     plt.figure(figsize=(10, 6))
   #     plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', marker='o', edgecolor='k')
   #     x_boundary = np.linspace(X[:, 0].min(), X[:, 0].max(), 100)
   #     y_boundary = -(weights[0] * x_boundary + bias) / weights[1]
   #     plt.plot(x_boundary, y_boundary, color='black')
   #     plt.xlabel('x1')
   #     plt.ylabel('x2')
   #     plt.title(f'Frontière de décision à l\'époque {epoch}')
   #     plt.show()

# Visualisation de la loss
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), loss_history, label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.title('Evolution de la loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Maintenant même chose avec du SGD

# %%
np.random.seed(10)
weights = np.random.randn(2)
bias = np.random.randn()
learning_rate = 0.1
epochs = 3

# Boucle d'entraînement avec SGD
loss_history = []

t0 = time.time()
for epoch in range(epochs):
    # Mélanger les données
    indices = np.random.permutation(num_samples)
    X_shuffled = X[indices]
    y_shuffled = y[indices]
    
    # Calcul de la loss globale
    #loss = 
    loss_history.append(loss)
    
    for i in range(num_samples):
        # Sélectionner un échantillon
        xi = X_shuffled[i]
        yi = y_shuffled[i]
        
        # Calcul des prédictions
        
        # Calcul des gradients
        
        # Mise à jour des poids et du biais


# Visualisation de la perte au cours des époques
plt.figure(figsize=(10, 6))
plt.plot(range(epochs), loss_history, label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()
